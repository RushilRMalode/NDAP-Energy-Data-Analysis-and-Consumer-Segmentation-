# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
import pandas as pd

file_path = 'Consumer_Dataset.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#    Unnamed: 0  Gender  Age Ever_Married  Family_Size     Profession Graduated  \
# 0           0    Male   22           No          4.0     Healthcare        No
# 1           1  Female   38          Yes          3.0       Engineer       Yes
# 2           2  Female   67          Yes          1.0       Engineer       Yes
# 3           3    Male   67          Yes          2.0         Lawyer       Yes
# 4           4  Female   40          Yes          6.0  Entertainment       Yes
#
#    Work_Experience Energy_Consumption Preferred_Renewable Group
# 0              1.0                Low               Hydro     D
# 1              NaN            Average               Hydro     A
# 2              1.0                Low               Solar     B
# 3              0.0               High               Solar     B
# 4              NaN               High               Solar     A

# %%
data=data.dropna()

# %%
energy_consumption_mapping = {
    'Low': 0,
    'Average': 100,
    'High': 200
}

data['Energy_Consumption'] = data['Energy_Consumption'].map(energy_consumption_mapping)

print("Unique values after encoding:", data['Energy_Consumption'].unique())
# Out:
# Unique values after encoding: [  0 200 100]

# %%
data_unsupervised = data.drop(['Group','Unnamed: 0'], axis=1)
data_unsupervised.head()
# Out:
#    Gender  Age Ever_Married  Family_Size  Profession Graduated  \
# 0    Male   22           No          4.0  Healthcare        No
# 2  Female   67          Yes          1.0    Engineer       Yes
# 3    Male   67          Yes          2.0      Lawyer       Yes
# 5    Male   56          Yes          2.0      Artist        No
# 6    Male   32           No          3.0  Healthcare       Yes
#
#    Work_Experience  Energy_Consumption Preferred_Renewable
# 0              1.0                   0               Hydro
# 2              1.0                   0               Solar
# 3              0.0                 200               Solar
# 5              0.0                 100               Solar
# 6              1.0                   0               Solar

# %%
data_unsupervised = pd.get_dummies(data_unsupervised, columns=['Gender', 'Ever_Married', 'Profession', 'Graduated', 'Preferred_Renewable'])
data_unsupervised.head()
# Out:
#    Age  Family_Size  Work_Experience  Energy_Consumption  Gender_Female  \
# 0   22          4.0              1.0                   0          False
# 2   67          1.0              1.0                   0           True
# 3   67          2.0              0.0                 200          False
# 5   56          2.0              0.0                 100          False
# 6   32          3.0              1.0                   0          False
#
#    Gender_Male  Ever_Married_No  Ever_Married_Yes  Profession_Artist  \
# 0         True             True             False              False
# 2        False            False              True              False
# 3         True            False              True              False
# 5         True            False              True               True
# 6         True             True             False              False
#
#    Profession_Doctor  ...  Profession_Marketing  Graduated_No  Graduated_Yes  \
# 0              False  ...                 False          True          False
# 2              False  ...                 False         False           True
# 3              False  ...                 False         False           True
# 5              False  ...                 False          True          False
# 6              False  ...                 False         False           True
#
#    Preferred_Renewable_Biomass  Preferred_Renewable_Geothermal  \
# 0                        False                           False
# 2                        False                           False
# 3                        False                           False
# 5                        False                           False
# 6                        False                           False
#
#    Preferred_Renewable_Hydro  Preferred_Renewable_Not Interested  \
# 0                       True                               False
# 2                      False                               False
# 3                      False                               False
# 5                      False                               False
# 6                      False                               False
#
#    Preferred_Renewable_Solar  Preferred_Renewable_Tidal  \
# 0                      False                      False
# 2                       True                      False
# 3                       True                      False
# 5                       True                      False
# 6                       True                      False
#
#    Preferred_Renewable_Wind
# 0                     False
# 2                     False
# 3                     False
# 5                     False
# 6                     False
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#data_unsupervised[['Age', 'Family_Size', 'Work_Experience', 'Energy_Consumption']] = scaler.fit_transform(data[['Age', 'Family_Size', 'Work_Experience', 'Energy_Consumption']])

# %%
k = 4
kmeans = KMeans(n_clusters=k, random_state=42)
data_unsupervised['Cluster'] = kmeans.fit_predict(data_unsupervised)

# Check the counts in each cluster
print(data_unsupervised['Cluster'].value_counts())
# Out:
# Cluster
# 3    2944
# 1    1662
# 0    1055
# 2    1004
# Name: count, dtype: int64

# %%
data_unsupervised['Cluster'] = kmeans.labels_
data_unsupervised['Group']=data['Group']
data_unsupervised.head()
# Out:
#    Age  Family_Size  Work_Experience  Energy_Consumption  Gender_Female  \
# 0   22          4.0              1.0                   0          False
# 2   67          1.0              1.0                   0           True
# 3   67          2.0              0.0                 200          False
# 5   56          2.0              0.0                 100          False
# 6   32          3.0              1.0                   0          False
#
#    Gender_Male  Ever_Married_No  Ever_Married_Yes  Profession_Artist  \
# 0         True             True             False              False
# 2        False            False              True              False
# 3         True            False              True              False
# 5         True            False              True               True
# 6         True             True             False              False
#
#    Profession_Doctor  ...  Graduated_Yes  Preferred_Renewable_Biomass  \
# 0              False  ...          False                        False
# 2              False  ...           True                        False
# 3              False  ...           True                        False
# 5              False  ...          False                        False
# 6              False  ...           True                        False
#
#    Preferred_Renewable_Geothermal  Preferred_Renewable_Hydro  \
# 0                           False                       True
# 2                           False                      False
# 3                           False                      False
# 5                           False                      False
# 6                           False                      False
#
#    Preferred_Renewable_Not Interested  Preferred_Renewable_Solar  \
# 0                               False                      False
# 2                               False                       True
# 3                               False                       True
# 5                               False                       True
# 6                               False                       True
#
#    Preferred_Renewable_Tidal  Preferred_Renewable_Wind  Cluster  Group
# 0                      False                     False        3      D
# 2                      False                     False        0      B
# 3                      False                     False        2      B
# 5                      False                     False        1      C
# 6                      False                     False        3      C
#
# [5 rows x 28 columns]

# %%
from collections import defaultdict

counts = defaultdict(lambda: defaultdict(int))

for index, row in data_unsupervised.iterrows():
    cluster_value = row['Cluster']
    segment_value = row['Group']
    counts[cluster_value][segment_value] += 1

total_counts = {cluster: sum(counts[cluster].values()) for cluster in counts}

print("Counts and Percentages:")
for cluster in sorted(counts.keys()):
    print(f"Cluster {cluster}:")
    for segment in 'ABCD':
        count = counts[cluster][segment]
        percentage = (count / total_counts[cluster]) * 100 if total_counts[cluster] > 0 else 0
        print(f"  {segment}: {count} ({percentage:.2f}%)")
# Out:
# Counts and Percentages:
# Cluster 0:
#   A: 351 (33.27%)
#   B: 322 (30.52%)
#   C: 196 (18.58%)
#   D: 186 (17.63%)
# Cluster 1:
#   A: 270 (16.25%)
#   B: 499 (30.02%)
#   C: 795 (47.83%)
#   D: 98 (5.90%)
# Cluster 2:
#   A: 214 (21.31%)
#   B: 315 (31.37%)
#   C: 370 (36.85%)
#   D: 105 (10.46%)
# Cluster 3:
#   A: 781 (26.53%)
#   B: 436 (14.81%)
#   C: 359 (12.19%)
#   D: 1368 (46.47%)

# %%
cluster_map = {0: 'C', 1: 'A', 2: 'D', 3: 'B'}

data_unsupervised['Predicted_Group'] = data_unsupervised['Cluster'].map(cluster_map)
data_unsupervised.head()
# Out:
#    Age  Family_Size  Work_Experience  Energy_Consumption  Gender_Female  \
# 0   22          4.0              1.0                   0          False
# 2   67          1.0              1.0                   0           True
# 3   67          2.0              0.0                 200          False
# 5   56          2.0              0.0                 100          False
# 6   32          3.0              1.0                   0          False
#
#    Gender_Male  Ever_Married_No  Ever_Married_Yes  Profession_Artist  \
# 0         True             True             False              False
# 2        False            False              True              False
# 3         True            False              True              False
# 5         True            False              True               True
# 6         True             True             False              False
#
#    Profession_Doctor  ...  Preferred_Renewable_Biomass  \
# 0              False  ...                        False
# 2              False  ...                        False
# 3              False  ...                        False
# 5              False  ...                        False
# 6              False  ...                        False
#
#    Preferred_Renewable_Geothermal  Preferred_Renewable_Hydro  \
# 0                           False                       True
# 2                           False                      False
# 3                           False                      False
# 5                           False                      False
# 6                           False                      False
#
#    Preferred_Renewable_Not Interested  Preferred_Renewable_Solar  \
# 0                               False                      False
# 2                               False                       True
# 3                               False                       True
# 5                               False                       True
# 6                               False                       True
#
#    Preferred_Renewable_Tidal  Preferred_Renewable_Wind  Cluster  Group  \
# 0                      False                     False        3      D
# 2                      False                     False        0      B
# 3                      False                     False        2      B
# 5                      False                     False        1      C
# 6                      False                     False        3      C
#
#    Predicted_Group
# 0                B
# 2                C
# 3                D
# 5                A
# 6                B
#
# [5 rows x 29 columns]

# %%
error = (data_unsupervised['Group'] != data_unsupervised['Predicted_Group']).sum()

percentage_error = (error / len(data_unsupervised)) * 100

print(f"Percentage Error: {percentage_error:.2f}%")
# Out:
# Percentage Error: 84.89%
